# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro0Oliveira/2024.1-TrabalhoN1_Tema2_Questionario_para_otimizacao_da_coleta/blob/main/Projeto_Residuos_Solidos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bairros_leste_natal = ['santos reis', 'rocas', 'ribeira', 'praia do meio', 'cidade alta', 'petrópolis', 'areia preta', 'mãe luiza', 'alecrim', 'barro vermelho', 'tirol', 'lagoa seca']

def questionario_usuario():
    while True:
        lix1 = input('Olá, qual o seu nome? (por favor use um nome verdadeiro, será importante na análise dos dados posteriormente) : ')
        if lix1.isalpha():
            break
        else:
            print('Digite um nome válido')

    while True:
        lix2 = input('Em que bairro da região leste de Natal-RN o Sr.(a) mora? ').strip().lower()
        if lix2 in bairros_leste_natal:
            print(f'Ótimo bairro')
            break
        else:
            print('Digite um bairro válido.')

    lix3 = input('Qual o nome da rua? (Por favor, informar somente ruas dos bairros da região Leste de Natal-RN) ')

    while True:
        lix4 = input('Poderia responder algumas perguntas para utilizarmos as informações na otimização do sistema de coleta em sua localidade? (Sim/Não) ').strip().lower()
        if lix4 == 'não':
            print('Ok, programa encerrado.')
            return
        elif lix4 == 'sim':
            break

    while True:
        lix5 = int(input('Quantas sacolas de lixo são utilizadas diariamente em sua residência? '))
        if lix5 < 1:
            print('Digite um valor maior ou igual a 1.')
        else:
            break

    while True:
        print('Sobre o tipo de sacola utilizada responda a seguir ')
        sac1 = int(input('Quantas sacolas pequenas de supermercado? '))
        if sac1 < 0:
            print('Digite um valor maior ou igual a 0.')
        else:
            break

    while True:
        sac2 = int(input('Quantas sacolas grandes de supermercado? '))
        if sac2 < 0:
            print('Digite um valor maior ou igual a 0.')
        else:
            break

    while True:
        sac3 = int(input('Quantas sacolas de 20 litros? '))
        if sac3 < 0:
            print('Digite um valor maior ou igual a 0.')
        else:
            break

    while True:
        sac4 = int(input('Quantas sacolas de 40 litros? '))
        if sac4 < 0:
            print('Digite um valor maior ou igual a 0.')
        else:
            break

    while True:
        sac5 = int(input('Quantas sacolas de 60 litros? '))
        if sac5 < 0:
            print('Digite um valor maior ou igual a 0.')
        else:
            break

    while True:
        sac6 = int(input('Quantas sacolas de 100 litros? '))
        if sac6 < 0:
            print('Digite um valor maior ou igual a 0.')
        else:
            break

    soma = (sac1*4) + (sac2*12) + (sac3*20) + (sac4*40) + (sac5*60) + (sac6*100)
    coleta = 10.000
    geral = coleta - soma
    while True:
        lix8 = input('Há problemas quanto ao acúmulo de lixo em sua rua? (Sim/Não) ').strip().lower()
        if lix8 == 'não':
            print('Ok, obrigado por responder o questionário. Programa encerrado.')
            break
        else:
            resp1 = input('Por favor, em poucas palavras, diga quais os problemas mais recorrentes que envolvam a coleta de lixo:')
            resp2 = input('Os moradores em sua residência sabem o dia e a previsão de horário que o caminhão de coleta passa? (Sim/Não) ').strip().lower()
            print('Obrigado pelas suas respostas!')
            print("Voçê produz diariamente", soma,"L de residuos.")

            break

def informacoes_gestor():
    print('Bem-vindo, gestor. Aqui estão as informações técnicas, para a tomada de decisão sobre a otimização da coleta, de resíduos no leste da cidade do Natal-RN.')
    print(" ")
    print("É produzido, por dia, 157 toneladas de resíduos, em média, na zona leste de Natal/RN, de acordo com o jornal Tribuna do Norte em 2019.")
    print(" ")
    print("A capacidade de um caminhão simples de coleta é superior a 10 toneladas ")
    print(" ")
    print("Pórem para seguir as diretrizes da lei 14.229/21, o caminhão de coleta só pode carregar até 9 toneladas.")
    print(" ")
    print("Seriam necessarios uma média de 18 caminhões coletores, por dia, para que não exista deficiência no sistema de coleta da região Leste de Natal-RN.")
    print(" ")
    print("Faz necessário uma coleta de informações mais atualizadas de uma média de resíduos sólidos produzido diariamente na região.")
    print(" ")
    print("Recomenda-se a divulgação do questionário referente a produção de resíduos para a população, por residência na região")
    print(" ")
    print("O questionário pode ser respondido via web ou aplicativo.")
    print(" ")
    print("Com essas informações a estratégia para a otimização da coleta poderá será definida, evitando o acúmulo de resíduos nas residências, da região.")



def main():
    while True:
        role = input('Você é um usuário ou gestor? (usuario/gestor) ').strip().lower()
        if role == 'usuario':
            questionario_usuario()
            break
        elif role == 'gestor':
            informacoes_gestor()
            break
        else:
            print('Por favor, digite "usuario" ou "gestor".')

if __name__ == '__main__':
  main()
# Out:
# Você é um usuário ou gestor? (usuario/gestor) usuario
# Olá, qual o seu nome? (por favor use um nome verdadeiro, será importante na análise dos dados posteriormente) : Jeremias
# Em que bairro da região leste de Natal-RN o Sr.(a) mora? rocas
# Ótimo bairro
# Qual o nome da rua? (Por favor, informar somente ruas dos bairros da região Leste de Natal-RN) Rua do Areial
# Poderia responder algumas perguntas para utilizarmos as informações na otimização do sistema de coleta em sua localidade? (Sim/Não) sim
# Quantas sacolas de lixo são utilizadas diariamente em sua residência? 5
# Sobre o tipo de sacola utilizada responda a seguir
# Quantas sacolas pequenas de supermercado? 3
# Quantas sacolas grandes de supermercado? 1
# Quantas sacolas de 20 litros? 1
# Quantas sacolas de 40 litros? 0
# Quantas sacolas de 60 litros? 0
# Quantas sacolas de 100 litros? 0
# Há problemas quanto ao acúmulo de lixo em sua rua? (Sim/Não) sim
# Por favor, em poucas palavras, diga quais os problemas mais recorrentes que envolvam a coleta de lixo:Falta de disponibilidade da coleta
# Os moradores em sua residência sabem o dia e a previsão de horário que o caminhão de coleta passa? (Sim/Não) sim
# Obrigado pelas suas respostas!
# Voçê produz diariamente 44 L de residuos.
